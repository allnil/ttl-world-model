# %%
from collect_data import collect_dataset, dataset_unique_transitions
import matplotlib.pyplot as plt
game_counts = [100, 500, 1000, 5000, 20000]
unique_counts = []

for n in game_counts:
  data = collect_dataset(n)
  unique_counts.append(dataset_unique_transitions(data))
  print(n, "партий →", unique_counts[-1], "уникальных пар")
# Out:
# 100 партий → 603 уникальных пар
# 500 партий → 2477 уникальных пар
# 1000 партий → 4302 уникальных пар
# 5000 партий → 11653 уникальных пар
# 20000 партий → 15977 уникальных пар

# %%
from collect_data import collect_dataset, dataset_unique_transitions
import matplotlib.pyplot as plt
game_counts = [100, 500, 1000, 5000, 20000, 50000, 100000]
unique_counts = []

for n in game_counts:
  data = collect_dataset(n)
  unique_counts.append(dataset_unique_transitions(data))
  print(n, "партий →", unique_counts[-1], "уникальных пар")
# Out:
# 100 партий → 603 уникальных пар
# 500 партий → 2477 уникальных пар
# 1000 партий → 4302 уникальных пар
# 5000 партий → 11653 уникальных пар
# 20000 партий → 15977 уникальных пар
# 50000 партий → 16167 уникальных пар
# 100000 партий → 16167 уникальных пар
